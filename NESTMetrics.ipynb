# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import uproot
from tqdm import trange
import matplotlib.patheffects as pe

import NESTModel

# %%
plt.figure()
plt.plot(np.linspace(0, 1000), NESTModel.NEST_DL(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('$D_L$ [cm$^2$/$\mu$s]')

print(NESTModel.NEST_DL(93))

plt.scatter(93, NESTModel.NEST_DL(93), marker="*", color='red')

plt.figure()
plt.plot(np.linspace(0, 1000), NESTModel.NEST_DV(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('$v_d$ [cm/$\mu$s]')

print(NESTModel.NEST_DV(93))

plt.scatter(93, NESTModel.NEST_DV(93), marker="*", color='red')

D = 145 # TPC height in cm

plt.figure()
plt.plot(np.linspace(0, 1000), D / NESTModel.NEST_DV(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('Drift Time [$\mu$s]')
plt.scatter(93, 1040, marker="*", color='red', label='LZ WS2024')
# Out:
# 40.45950280079807
# 0.13723596957140163
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:13: SyntaxWarning: invalid escape sequence '\m'
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_630/2904348815.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$D_L$ [cm$^2$/$\mu$s]')
# /tmp/ipykernel_630/2904348815.py:13: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$v_d$ [cm/$\mu$s]')
# /tmp/ipykernel_630/2904348815.py:24: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('Drift Time [$\mu$s]')
# /tmp/ipykernel_630/2904348815.py:22: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(np.linspace(0, 1000), D / NESTModel.NEST_DV(np.linspace(0, 1000)))
