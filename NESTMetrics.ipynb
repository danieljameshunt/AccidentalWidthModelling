# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import uproot
from tqdm import trange
import matplotlib.patheffects as pe

import NESTModel

# %%
plt.figure()
plt.plot(np.linspace(0, 1000), NESTModel.NEST_DL(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('$D_L$ [cm$^2$/$\mu$s]')

plt.figure()
plt.plot(np.linspace(0, 1000), NESTModel.NEST_DV(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('$v_d$ [cm/$\mu$s]')

D = 145 # TPC height in cm

plt.figure()
plt.plot(np.linspace(0, 1000), D / NESTModel.NEST_DV(np.linspace(0, 1000)))
plt.xlabel('Drift Field [V/cm]')
plt.ylabel('Drift Time [$\mu$s]')
plt.scatter(93, 1040, marker="*", color='red', label='LZ WS2024')
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_295/3204947920.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$D_L$ [cm$^2$/$\mu$s]')
# /tmp/ipykernel_295/3204947920.py:9: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$v_d$ [cm/$\mu$s]')
# /tmp/ipykernel_295/3204947920.py:16: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('Drift Time [$\mu$s]')
# /home/dhunt/AccidentalWidthModelling/NESTModel.py:4: RuntimeWarning: divide by zero encountered in power
#   par1 = A*np.power(F, APow)
# /home/dhunt/AccidentalWidthModelling/NESTModel.py:9: RuntimeWarning: divide by zero encountered in divide
#   return np.exp(A - B/x + C*np.log10(x))
# /home/dhunt/AccidentalWidthModelling/NESTModel.py:9: RuntimeWarning: divide by zero encountered in log10
#   return np.exp(A - B/x + C*np.log10(x))
# /tmp/ipykernel_295/3204947920.py:14: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(np.linspace(0, 1000), D / NESTModel.NEST_DV(np.linspace(0, 1000)))
